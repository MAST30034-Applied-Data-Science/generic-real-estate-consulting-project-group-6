# %% [markdown]
# # Preprocess
# 1. Merge API request data to property data
# 2. Preprocess property data
# 3. Merge other relevant features

# %% [markdown]
# ### Load Raw property data

# %%
import numpy as np
import pandas as pd
import json
import seaborn as sns
import geopandas as gpd
from geopandas.tools import sjoin
# Out:
# /opt/anaconda3/envs/ads/lib/python3.8/site-packages/geopandas/_compat.py:112: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
pd.options.mode.chained_assignment = None
# Read the data
# with open('../data/raw/property_raw.json','r',encoding='utf8')as fp:
#     json_data = json.load(fp)

# df = pd.DataFrame(json_data.values())
df = pd.read_json('../data/raw/property_raw.json')
df = df.transpose()
df = df.reset_index(drop=True)
df
# Out:
#                                                     name       cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000   $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...         $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000   $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000            $350
# ...                                                  ...             ...
# 15342            28 Beachcomber Drive Inverloch VIC 3996         $550 wk
# 15343             14 Inverloch Parade Inverloch VIC 3996         $420 wk
# 15344              10 Hopetoun Street Inverloch VIC 3996         $370 wk
# 15345                                 Inverloch VIC 3996         $475 wk
# 15346                 64 Dixon Street Inverloch VIC 3996   Contact Agent
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 15342  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 15343  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 15344  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 15345  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
# 15346   [-38.6313719, 145.717275]               [1 Bed, 1 Bath]
#
#                           type
# 0      Apartment / Unit / Flat
# 1      Apartment / Unit / Flat
# 2      Apartment / Unit / Flat
# 3      Apartment / Unit / Flat
# 4      Apartment / Unit / Flat
# ...                        ...
# 15342                    House
# 15343                    House
# 15344                    House
# 15345                    House
# 15346                    House
#
# [15347 rows x 5 columns]

# %% [markdown]
# #### Merge the distance to school, station and CBD
# 1. Merge School distance
# 2. Merge station distance
# 3. Merge CBD distance

# %%
dist_train = pd.read_csv("../data/raw/properties_train_proximity.csv")
dist_school = pd.read_csv("../data/raw/properties_shcool_proximity.csv")
dist_CBD = pd.read_csv("../data/raw/CBD_distance.csv")

# %%
df["cloest station"] = dist_train['closest station'].map(lambda x : str(x))
df["station_distance"] = dist_train['proximity to train station']

df['cloest school'] = dist_school['closest school'].map(lambda x : str(x))
df["school_distance"] = dist_school['proximity to scholl']

df['CBD_distance'] = dist_CBD["CBD_distance"]

# %% [markdown]
# ### Preprocess property features
# 1. Split postcode and address
# 2. Unify cost measurement to weekly payment
# 3. Split 'rooms' to number of bedrooms, bathrooms and parking

# %%
# get postcode and address from name
ps_code = df['name']
ps_code1 = list(ps_code)
add = list(ps_code)
for i in range(len(ps_code1)-1):
    ps_code1[i] = ps_code1[i][-4:]
for i in range(len(add)-1):
    add[i] = add[i][:-9]
    
df['postcode'] = ps_code1
df['address'] = add
df
# Out:
#                                                     name       cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000   $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...         $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000   $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000            $350
# ...                                                  ...             ...
# 15342            28 Beachcomber Drive Inverloch VIC 3996         $550 wk
# 15343             14 Inverloch Parade Inverloch VIC 3996         $420 wk
# 15344              10 Hopetoun Street Inverloch VIC 3996         $370 wk
# 15345                                 Inverloch VIC 3996         $475 wk
# 15346                 64 Dixon Street Inverloch VIC 3996   Contact Agent
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 15342  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 15343  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 15344  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 15345  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
# 15346   [-38.6313719, 145.717275]               [1 Bed, 1 Bath]
#
#                           type cloest station  station_distance cloest school  \
# 0      Apartment / Unit / Flat             30           1803.65          1374
# 1      Apartment / Unit / Flat            176            371.68          2265
# 2      Apartment / Unit / Flat             28            248.50          2189
# 3      Apartment / Unit / Flat            140            404.26          2193
# 4      Apartment / Unit / Flat             28            525.08          2265
# ...                        ...            ...               ...           ...
# 15342                    House            181          65073.96           447
# 15343                    House            181          69323.16           447
# 15344                    House            181          68313.03           447
# 15345                    House            181          68459.23           447
# 15346                    House            181          67308.83           447
#
#        school_distance  CBD_distance                            postcode  \
# 0               667.06       1702.19                                3000
# 1               352.49       2267.13                                3000
# 2               401.73       1937.39                                3000
# 3               586.61        790.13                                3000
# 4               779.91       1657.95                                3000
# ...                ...           ...                                 ...
# 15342          3338.25     146939.64                                3996
# 15343           944.91     147493.50                                3996
# 15344           516.17     147082.53                                3996
# 15345            68.42     146682.64                                3996
# 15346          1361.75     145916.84  64 Dixon Street Inverloch VIC 3996
#
#                                          address
# 0               1901/368 St Kilda Road Melbourne
# 1              1211/200 Spencer Street Melbourne
# 2      1008/380 Little Lonsdale Street Melbourne
# 3                   3/27 Flinders Lane Melbourne
# 4              611/408 Lonsdale Street Melbourne
# ...                                          ...
# 15342             28 Beachcomber Drive Inverloch
# 15343              14 Inverloch Parade Inverloch
# 15344               10 Hopetoun Street Inverloch
# 15345                                  Inverloch
# 15346         64 Dixon Street Inverloch VIC 3996
#
# [15347 rows x 12 columns]

# %%
# extract cost value
# Remove the comma
df['cost_text'] = df.cost_text.astype(str).str.replace(r',', '')

import numpy as np
df['cost'] = df.cost_text.str.extract(r"\$(\d*\.?\d+)", expand=True)
df=df.dropna()
df['cost'] = pd.to_numeric(df['cost'])
df['cost'] = df['cost'].astype(int)
df = df.reset_index(drop=True)

df['text'] = df.cost_text.str.extract("\d\s*([a-zA-Z]+\s*[a-zA-Z]+\s*[a-zA-Z]*)")

# Turn monthly cost into weekly cost
df.cost[(df['cost_text'].str.contains('w|W|/W')==False) & (df['text'].str.contains("month|pcm|pm|PCM|mth|Month")) &(df['text'].isnull() == False)] /= 4.34
# Turn fornightly cost into weekly cost
df.cost[df['cost_text'].str.contains("Fortnight|fornight")&(df['text'].isnull() == False)]/=2
# Turn annual cost into weekly cost
df.cost[(df['cost_text'].str.contains("Night|night") == False) & (df['cost_text'].str.contains("Fortnight|fornight|Fortnightly")== False) &
(df['cost_text'].str.contains('w|W|/W')==False) & df['cost_text'].str.contains("year|Year|annum|pa|Annual|p\.a")] /= 52
# Turn day by day cost into weekly cost
df.cost[(df['cost_text'].str.contains("Fortnight|fornight") == False) & df['cost_text'].str.contains("Night|night")&(df['text'].isnull() == False)] *= 7

# Correct a few miswritten lines in 'cost_text'
df.cost.iloc[[4389,4527,6018,6035,8108,9619]] *= 4.34
df = df.reset_index(drop=True)
df = df.drop([10364,11847])

# Keep the cost less than $10000
df = df[df['cost']<10000]

df.cost.describe()
# Out:
# count    14750.000000
# mean       514.283754
# std        274.110505
# min          1.000000
# 25%        385.000000
# 50%        450.000000
# 75%        560.000000
# max       5600.000000
# Name: cost, dtype: float64

# %%
# extract postcode frome the feature 'name'
df['postcode'] = df['name'].apply(lambda x:x.split(' ')[-1])
df = df.reset_index(drop=True)
df
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14745          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14746            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14747             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14748              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14749                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14745   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14746  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14747  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14748  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14749  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type cloest station  station_distance cloest school  \
# 0      Apartment / Unit / Flat             30           1803.65          1374
# 1      Apartment / Unit / Flat            176            371.68          2265
# 2      Apartment / Unit / Flat             28            248.50          2189
# 3      Apartment / Unit / Flat            140            404.26          2193
# 4      Apartment / Unit / Flat             28            525.08          2265
# ...                        ...            ...               ...           ...
# 14745                    House            181          67815.19           447
# 14746                    House            181          65073.96           447
# 14747                    House            181          69323.16           447
# 14748                    House            181          68313.03           447
# 14749                    House            181          68459.23           447
#
#        school_distance  CBD_distance postcode  \
# 0               667.06       1702.19     3000
# 1               352.49       2267.13     3000
# 2               401.73       1937.39     3000
# 3               586.61        790.13     3000
# 4               779.91       1657.95     3000
# ...                ...           ...      ...
# 14745           596.78     146677.31     3996
# 14746          3338.25     146939.64     3996
# 14747           944.91     147493.50     3996
# 14748           516.17     147082.53     3996
# 14749            68.42     146682.64     3996
#
#                                          address    cost      text
# 0               1901/368 St Kilda Road Melbourne  1800.0  Per Week
# 1              1211/200 Spencer Street Melbourne   480.0  per week
# 2      1008/380 Little Lonsdale Street Melbourne   400.0        pw
# 3                   3/27 Flinders Lane Melbourne   420.0  per week
# 4              611/408 Lonsdale Street Melbourne   350.0       NaN
# ...                                          ...     ...       ...
# 14745           16B Sandy Mount Avenue Inverloch   400.0  per week
# 14746             28 Beachcomber Drive Inverloch   550.0        wk
# 14747              14 Inverloch Parade Inverloch   420.0        wk
# 14748               10 Hopetoun Street Inverloch   370.0        wk
# 14749                                  Inverloch   475.0        wk
#
# [14750 rows x 14 columns]

# %%
# split rooms into different part
# count missing values in 'rooms'
list(df['rooms']).count([])
# remove missing value
df=df[df['rooms'].str.len()!=0]
df = df.reset_index(drop=True)
rooms =df['rooms']

bedroom = []
bath = []
parking = []

for i in range(len(rooms)):
    if (rooms[i][0][-4:] == 'Beds') or (rooms[i][0][-3:] == 'Bed'):
        bedroom.append(rooms[i][0][0])
       
for j in range(len(rooms)):
    if (rooms[j][1][-5:] == 'Baths') or (rooms[j][1][-4:] == 'Bath'):
        bath.append(rooms[j][1][0])

for j in range(len(rooms)):
    if len(rooms[j]) != 3:
        parking.append('0')
    elif(rooms[j][2][2:] == 'Parking'):
        parking.append(rooms[j][2][0])

df['beds'] = bedroom
df['bath'] = bath
df['parking'] = parking
df
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14721          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14722            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14723             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14724              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14725                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14721   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14722  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14723  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14724  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14725  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type cloest station  station_distance cloest school  \
# 0      Apartment / Unit / Flat             30           1803.65          1374
# 1      Apartment / Unit / Flat            176            371.68          2265
# 2      Apartment / Unit / Flat             28            248.50          2189
# 3      Apartment / Unit / Flat            140            404.26          2193
# 4      Apartment / Unit / Flat             28            525.08          2265
# ...                        ...            ...               ...           ...
# 14721                    House            181          67815.19           447
# 14722                    House            181          65073.96           447
# 14723                    House            181          69323.16           447
# 14724                    House            181          68313.03           447
# 14725                    House            181          68459.23           447
#
#        school_distance  CBD_distance postcode  \
# 0               667.06       1702.19     3000
# 1               352.49       2267.13     3000
# 2               401.73       1937.39     3000
# 3               586.61        790.13     3000
# 4               779.91       1657.95     3000
# ...                ...           ...      ...
# 14721           596.78     146677.31     3996
# 14722          3338.25     146939.64     3996
# 14723           944.91     147493.50     3996
# 14724           516.17     147082.53     3996
# 14725            68.42     146682.64     3996
#
#                                          address    cost      text beds bath  \
# 0               1901/368 St Kilda Road Melbourne  1800.0  Per Week    3    2
# 1              1211/200 Spencer Street Melbourne   480.0  per week    1    1
# 2      1008/380 Little Lonsdale Street Melbourne   400.0        pw    1    1
# 3                   3/27 Flinders Lane Melbourne   420.0  per week    1    1
# 4              611/408 Lonsdale Street Melbourne   350.0       NaN    1    1
# ...                                          ...     ...       ...  ...  ...
# 14721           16B Sandy Mount Avenue Inverloch   400.0  per week    2    1
# 14722             28 Beachcomber Drive Inverloch   550.0        wk    4    2
# 14723              14 Inverloch Parade Inverloch   420.0        wk    2    1
# 14724               10 Hopetoun Street Inverloch   370.0        wk    2    1
# 14725                                  Inverloch   475.0        wk    3    2
#
#       parking
# 0           2
# 1           1
# 2           0
# 3           0
# 4           0
# ...       ...
# 14721       1
# 14722       0
# 14723       0
# 14724       1
# 14725       1
#
# [14726 rows x 17 columns]

# %% [markdown]
# ### Merge other features to property dataset
# 1. Find out property cooresponding SA2
# 2. Find out property cooresponding Suburb
# 3. Merge SA2 scaled crime index

# %% [markdown]
# ##### Use geopands to map property to SA2 and Suburb

# %%
SA2_shape = gpd.read_file("../data/raw/external_data/SA2_shape/SA2_2021_AUST_GDA2020.shp")
suburb_shape = gpd.read_file("../data/raw/external_data/vic_localities/vic_localities.shp")
SA2_shape_2016 = gpd.read_file("../data/raw/external_data/SA2_shape_2016/SA2_2016_AUST.shp")

# %%
# Select certain rage of points
SA2_shape = SA2_shape[SA2_shape['STE_NAME21'] == 'Victoria']
SA2_shape = SA2_shape[["SA2_CODE21", "geometry"]]
suburb_shape = suburb_shape[['LOC_PID', 'LOC_NAME', 'geometry']]
SA2_shape_2016 = SA2_shape_2016[SA2_shape_2016['STE_NAME16'] == 'Victoria']
SA2_shape_2016 = SA2_shape_2016[["SA2_MAIN16", "geometry"]]

# %%
SA2_shape
# Out:
#      SA2_CODE21                                           geometry
# 644   201011001  POLYGON ((143.78282 -37.56666, 143.75558 -37.5...
# 645   201011002  POLYGON ((143.81896 -37.55582, 143.81644 -37.5...
# 646   201011005  POLYGON ((143.84171 -37.61596, 143.84176 -37.6...
# 647   201011006  POLYGON ((143.75050 -37.59119, 143.75044 -37.5...
# 648   201011007  POLYGON ((143.73296 -37.62333, 143.73263 -37.6...
# ...         ...                                                ...
# 1163  217041478  MULTIPOLYGON (((142.00870 -38.41715, 142.00876...
# 1164  217041479  POLYGON ((142.43668 -38.35544, 142.43658 -38.3...
# 1165  217041480  POLYGON ((142.45281 -38.39126, 142.45230 -38.3...
# 1166  297979799                                               None
# 1167  299999499                                               None
#
# [524 rows x 2 columns]

# %%
SA2_shape_2016
# Out:
#      SA2_MAIN16                                           geometry
# 578   201011001  POLYGON ((143.70477 -37.51935, 143.70482 -37.5...
# 579   201011002  POLYGON ((143.81896 -37.55583, 143.81644 -37.5...
# 580   201011003  POLYGON ((143.85013 -37.54247, 143.85011 -37.5...
# 581   201011004  POLYGON ((143.82821 -37.57559, 143.82840 -37.5...
# 582   201011005  POLYGON ((143.84170 -37.61597, 143.84175 -37.6...
# ...         ...                                                ...
# 1037  217041478  MULTIPOLYGON (((142.00869 -38.41716, 142.00876...
# 1038  217041479  POLYGON ((142.43668 -38.35545, 142.43658 -38.3...
# 1039  217041480  POLYGON ((142.52511 -38.38390, 142.52505 -38.3...
# 1040  297979799                                               None
# 1041  299999499                                               None
#
# [464 rows x 2 columns]

# %%
# Convert property location to geopandas datatype POINT
df_geo = df
df_geo['Longitude'] = df['coordinates'].map(lambda x : x[1])
df_geo['Latitude'] = df['coordinates'].map(lambda x : x[0])
df_geo = gpd.GeoDataFrame(
        df_geo, geometry=gpd.points_from_xy(df_geo.Longitude, df_geo.Latitude))
df_geo.set_crs(epsg=7844, inplace=True)
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14721          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14722            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14723             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14724              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14725                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14721   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14722  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14723  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14724  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14725  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type cloest station  station_distance cloest school  \
# 0      Apartment / Unit / Flat             30           1803.65          1374
# 1      Apartment / Unit / Flat            176            371.68          2265
# 2      Apartment / Unit / Flat             28            248.50          2189
# 3      Apartment / Unit / Flat            140            404.26          2193
# 4      Apartment / Unit / Flat             28            525.08          2265
# ...                        ...            ...               ...           ...
# 14721                    House            181          67815.19           447
# 14722                    House            181          65073.96           447
# 14723                    House            181          69323.16           447
# 14724                    House            181          68313.03           447
# 14725                    House            181          68459.23           447
#
#        school_distance  CBD_distance postcode  \
# 0               667.06       1702.19     3000
# 1               352.49       2267.13     3000
# 2               401.73       1937.39     3000
# 3               586.61        790.13     3000
# 4               779.91       1657.95     3000
# ...                ...           ...      ...
# 14721           596.78     146677.31     3996
# 14722          3338.25     146939.64     3996
# 14723           944.91     147493.50     3996
# 14724           516.17     147082.53     3996
# 14725            68.42     146682.64     3996
#
#                                          address    cost      text beds bath  \
# 0               1901/368 St Kilda Road Melbourne  1800.0  Per Week    3    2
# 1              1211/200 Spencer Street Melbourne   480.0  per week    1    1
# 2      1008/380 Little Lonsdale Street Melbourne   400.0        pw    1    1
# 3                   3/27 Flinders Lane Melbourne   420.0  per week    1    1
# 4              611/408 Lonsdale Street Melbourne   350.0       NaN    1    1
# ...                                          ...     ...       ...  ...  ...
# 14721           16B Sandy Mount Avenue Inverloch   400.0  per week    2    1
# 14722             28 Beachcomber Drive Inverloch   550.0        wk    4    2
# 14723              14 Inverloch Parade Inverloch   420.0        wk    2    1
# 14724               10 Hopetoun Street Inverloch   370.0        wk    2    1
# 14725                                  Inverloch   475.0        wk    3    2
#
#       parking   Longitude   Latitude                     geometry
# 0           2  144.971027 -37.831809  POINT (144.97103 -37.83181)
# 1           1  144.953247 -37.816228  POINT (144.95325 -37.81623)
# 2           0  144.958129 -37.812103  POINT (144.95813 -37.81210)
# 3           0  144.973365 -37.814732  POINT (144.97337 -37.81473)
# 4           0  144.960401 -37.812598  POINT (144.96040 -37.81260)
# ...       ...         ...        ...                          ...
# 14721       1  145.725239 -38.634001  POINT (145.72524 -38.63400)
# 14722       0  145.703128 -38.641250  POINT (145.70313 -38.64125)
# 14723       0  145.735808 -38.628714  POINT (145.73581 -38.62871)
# 14724       1  145.730686 -38.634124  POINT (145.73069 -38.63412)
# 14725       1  145.729364 -38.631461  POINT (145.72936 -38.63146)
#
# [14726 rows x 20 columns]

# %%
df_geo_SA2 = sjoin(df_geo, SA2_shape, how="left")
df_geo_SA2 = df_geo_SA2.drop(columns="index_right")
df_geo_SA2_suburb = sjoin(df_geo_SA2, suburb_shape, how='left')
df_geo_SA2_suburb = df_geo_SA2_suburb.drop(columns="index_right")
SA2_shape_2016.set_crs(epsg=7844, inplace=True, allow_override=True)
df_geo_SA2_suburb_16= sjoin(df_geo_SA2_suburb, SA2_shape_2016, how="left")
df_geo_SA2_suburb_16 = df_geo_SA2_suburb_16.drop(columns=["index_right", 'geometry', 'coordinates'])

# %%
df_geo_SA2_suburb_16
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14721          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14722            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14723             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14724              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14725                                 Inverloch VIC 3996           $475 wk
#
#                               rooms                     type cloest station  \
# 0      [3 Beds, 2 Baths, 2 Parking]  Apartment / Unit / Flat             30
# 1        [1 Bed, 1 Bath, 1 Parking]  Apartment / Unit / Flat            176
# 2                   [1 Bed, 1 Bath]  Apartment / Unit / Flat             28
# 3                   [1 Bed, 1 Bath]  Apartment / Unit / Flat            140
# 4                   [1 Bed, 1 Bath]  Apartment / Unit / Flat             28
# ...                             ...                      ...            ...
# 14721   [2 Beds, 1 Bath, 1 Parking]                    House            181
# 14722             [4 Beds, 2 Baths]                    House            181
# 14723              [2 Beds, 1 Bath]                    House            181
# 14724   [2 Beds, 1 Bath, 1 Parking]                    House            181
# 14725  [3 Beds, 2 Baths, 1 Parking]                    House            181
#
#        station_distance cloest school  school_distance  CBD_distance postcode  \
# 0               1803.65          1374           667.06       1702.19     3000
# 1                371.68          2265           352.49       2267.13     3000
# 2                248.50          2189           401.73       1937.39     3000
# 3                404.26          2193           586.61        790.13     3000
# 4                525.08          2265           779.91       1657.95     3000
# ...                 ...           ...              ...           ...      ...
# 14721          67815.19           447           596.78     146677.31     3996
# 14722          65073.96           447          3338.25     146939.64     3996
# 14723          69323.16           447           944.91     147493.50     3996
# 14724          68313.03           447           516.17     147082.53     3996
# 14725          68459.23           447            68.42     146682.64     3996
#
#        ...      text  beds bath parking   Longitude   Latitude  SA2_CODE21  \
# 0      ...  Per Week     3    2       2  144.971027 -37.831809   206051512
# 1      ...  per week     1    1       1  144.953247 -37.816228   206041505
# 2      ...        pw     1    1       0  144.958129 -37.812103   206041505
# 3      ...  per week     1    1       0  144.973365 -37.814732   206041503
# 4      ...       NaN     1    1       0  144.960401 -37.812598   206041504
# ...    ...       ...   ...  ...     ...         ...        ...         ...
# 14721  ...  per week     2    1       1  145.725239 -38.634001   205031093
# 14722  ...        wk     4    2       0  145.703128 -38.641250   205031093
# 14723  ...        wk     2    1       0  145.735808 -38.628714   205031093
# 14724  ...        wk     2    1       1  145.730686 -38.634124   205031093
# 14725  ...        wk     3    2       1  145.729364 -38.631461   205031093
#
#                LOC_PID   LOC_NAME SA2_MAIN16
# 0      loc9901d119afda  Melbourne  206051132
# 1      loc9901d119afda  Melbourne  206041122
# 2      loc9901d119afda  Melbourne  206041122
# 3      loc9901d119afda  Melbourne  206041122
# 4      loc9901d119afda  Melbourne  206041122
# ...                ...        ...        ...
# 14721  loc1954186172da  Inverloch  205031093
# 14722  loc1954186172da  Inverloch  205031093
# 14723  loc1954186172da  Inverloch  205031093
# 14724  loc1954186172da  Inverloch  205031093
# 14725  loc1954186172da  Inverloch  205031093
#
# [14726 rows x 22 columns]

# %%
df_geo_SA2_suburb_16.to_csv("../data/raw/properties_preporcessed_1.csv")

# %%
# # read postcode file and remove duplicates on 'postcode'
# postcode_df = pd.read_csv("../data/raw/external_data/australian_postcodes.csv")
# postcode_df = postcode_df.drop_duplicates(subset=['postcode'])

# # The 'postcode' value types in the two dataframe are different. Convert df to int
# df['postcode'] = pd.to_numeric(df['postcode']).astype(int)


# # merge two dataframe and select features
# df_merge = pd.merge(df, postcode_df,on="postcode",how="left")
# # df_merge = df_merge[['name','cost','coordinates','type_x','address','beds','bath','parking','postcode','SA2_MAINCODE_2016']]
# df_merge
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14721          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14722            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14723             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14724              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14725                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14721   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14722  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14723  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14724  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14725  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                         type_x cloest station  station_distance cloest school  \
# 0      Apartment / Unit / Flat             30           1803.65          1374
# 1      Apartment / Unit / Flat            176            371.68          2265
# 2      Apartment / Unit / Flat             28            248.50          2189
# 3      Apartment / Unit / Flat            140            404.26          2193
# 4      Apartment / Unit / Flat             28            525.08          2265
# ...                        ...            ...               ...           ...
# 14721                    House            181          67815.19           447
# 14722                    House            181          65073.96           447
# 14723                    House            181          69323.16           447
# 14724                    House            181          68313.03           447
# 14725                    House            181          68459.23           447
#
#        school_distance  CBD_distance  ...  MMM_2015 MMM_2019        ced  \
# 0               667.06       1702.19  ...       1.0      1.0  Melbourne
# 1               352.49       2267.13  ...       1.0      1.0  Melbourne
# 2               401.73       1937.39  ...       1.0      1.0  Melbourne
# 3               586.61        790.13  ...       1.0      1.0  Melbourne
# 4               779.91       1657.95  ...       1.0      1.0  Melbourne
# ...                ...           ...  ...       ...      ...        ...
# 14721           596.78     146677.31  ...       5.0      4.0     Monash
# 14722          3338.25     146939.64  ...       5.0      4.0     Monash
# 14723           944.91     147493.50  ...       5.0      4.0     Monash
# 14724           516.17     147082.53  ...       5.0      4.0     Monash
# 14725            68.42     146682.64  ...       5.0      4.0     Monash
#
#         altitude chargezone phn_code                 phn_name  \
# 0      15.244751         V1   PHN201  North Western Melbourne
# 1      15.244751         V1   PHN201  North Western Melbourne
# 2      15.244751         V1   PHN201  North Western Melbourne
# 3      15.244751         V1   PHN201  North Western Melbourne
# 4      15.244751         V1   PHN201  North Western Melbourne
# ...          ...        ...      ...                      ...
# 14721        NaN         V2   PHN204                Gippsland
# 14722        NaN         V2   PHN204                Gippsland
# 14723        NaN         V2   PHN204                Gippsland
# 14724        NaN         V2   PHN204                Gippsland
# 14725        NaN         V2   PHN204                Gippsland
#
#              lgaregion electorate    electoraterating
# 0            Melbourne  Melbourne  Inner Metropolitan
# 1            Melbourne  Melbourne  Inner Metropolitan
# 2            Melbourne  Melbourne  Inner Metropolitan
# 3            Melbourne  Melbourne  Inner Metropolitan
# 4            Melbourne  Melbourne  Inner Metropolitan
# ...                ...        ...                 ...
# 14721  South Gippsland     Monash               Rural
# 14722  South Gippsland     Monash               Rural
# 14723  South Gippsland     Monash               Rural
# 14724  South Gippsland     Monash               Rural
# 14725  South Gippsland     Monash               Rural
#
# [14726 rows x 52 columns]

# %%
# crime = pd.read_csv('../data/raw/external_data/crime_completed.csv', index_col=[0])
# crime
# Out:
#      postcode  Offence Count     SA2 code  ERP 2021      scaled  \
# 0        3000          37272  206041122.0   47192.0    0.789795
# 1        3002           2429  206041119.0    5803.0    0.418577
# 2        3003           2708  206041127.0       3.0  902.666667
# 3        3004           2415  412082251.0   32825.0    0.073572
# 4        3005            174  206041118.0   14821.0    0.011740
# ..        ...            ...          ...       ...         ...
# 691      3990              5  205031093.0   26044.0    0.000192
# 692      3991            118  205031093.0   26044.0    0.004531
# 693      3992            206  205031093.0   26044.0    0.007910
# 694      3995           2179  205031093.0   26044.0    0.083666
# 695      3996            531  410062180.0   35361.0    0.015017
#
#      scaled_crime_rate
# 0             0.789795
# 1             0.418577
# 2           902.666667
# 3             0.073572
# 4             0.011740
# ..                 ...
# 691           0.000192
# 692           0.004531
# 693           0.007910
# 694           0.083666
# 695           0.015017
#
# [696 rows x 6 columns]

# %%
# df_merge = df_merge.rename(columns={'proximity to train station' : 'station_distance', 'type_x' : 'type', 'SA2_MAINCODE_2016' : 'SA2_CODE'})
# df_merge['SA2_CODE'] = df_merge['SA2_CODE'].astype('int64')
# income_df = pd.read_csv('../data/raw/external_data/income_complete.csv')
# income_df = income_df.rename(columns={'SA2' : 'SA2_CODE'})
# df_merge = pd.merge(df_merge, income_df[['SA2_CODE', '2022 pred']], on="SA2_CODE", how="left")
# population = pd.read_csv('../data/raw/external_data/population_complete.csv')
# population = population.rename(columns={'SA2 code' : 'SA2_CODE'})
# df_merge = pd.merge(df_merge, population[['SA2_CODE', 'ERP 2021', 'density 2021 persons/km2']], on="SA2_CODE", how="left")
# crime = pd.read_csv('../data/raw/external_data/crime_completed.csv', index_col=[0])
# df_merge = pd.merge(df_merge, crime[['postcode', 'scaled_crime_rate']], on='postcode', how='left')
# df_merge
# Out:
#                                                     name    cost  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  1800.0
# 1             1211/200 Spencer Street Melbourne VIC 3000   480.0
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...   400.0
# 3                  3/27 Flinders Lane Melbourne VIC 3000   420.0
# 4             611/408 Lonsdale Street Melbourne VIC 3000   350.0
# ...                                                  ...     ...
# 14721          16B Sandy Mount Avenue Inverloch VIC 3996   400.0
# 14722            28 Beachcomber Drive Inverloch VIC 3996   550.0
# 14723             14 Inverloch Parade Inverloch VIC 3996   420.0
# 14724              10 Hopetoun Street Inverloch VIC 3996   370.0
# 14725                                 Inverloch VIC 3996   475.0
#
#                       coordinates                     type  \
# 0      [-37.8318086, 144.9710272]  Apartment / Unit / Flat
# 1       [-37.816228, 144.9532465]  Apartment / Unit / Flat
# 2      [-37.8121026, 144.9581291]  Apartment / Unit / Flat
# 3      [-37.8147317, 144.9733655]  Apartment / Unit / Flat
# 4      [-37.8125979, 144.9604012]  Apartment / Unit / Flat
# ...                           ...                      ...
# 14721   [-38.6340011, 145.725239]                    House
# 14722  [-38.6412502, 145.7031282]                    House
# 14723  [-38.6287143, 145.7358082]                    House
# 14724  [-38.6341243, 145.7306862]                    House
# 14725  [-38.6314613, 145.7293638]                    House
#
#                                          address beds bath parking  postcode  \
# 0               1901/368 St Kilda Road Melbourne    3    2       2      3000
# 1              1211/200 Spencer Street Melbourne    1    1       1      3000
# 2      1008/380 Little Lonsdale Street Melbourne    1    1       0      3000
# 3                   3/27 Flinders Lane Melbourne    1    1       0      3000
# 4              611/408 Lonsdale Street Melbourne    1    1       0      3000
# ...                                          ...  ...  ...     ...       ...
# 14721           16B Sandy Mount Avenue Inverloch    2    1       1      3996
# 14722             28 Beachcomber Drive Inverloch    4    2       0      3996
# 14723              14 Inverloch Parade Inverloch    2    1       0      3996
# 14724               10 Hopetoun Street Inverloch    2    1       1      3996
# 14725                                  Inverloch    3    2       1      3996
#
#         SA2_CODE     2022 pred  ERP 2021  density 2021 persons/km2  \
# 0      206041122  30531.488067   47192.0                   19920.0
# 1      206041122  30531.488067   47192.0                   19920.0
# 2      206041122  30531.488067   47192.0                   19920.0
# 3      206041122  30531.488067   47192.0                   19920.0
# 4      206041122  30531.488067   47192.0                   19920.0
# ...          ...           ...       ...                       ...
# 14721  205031093  14259.334891   26044.0                      35.0
# 14722  205031093  14259.334891   26044.0                      35.0
# 14723  205031093  14259.334891   26044.0                      35.0
# 14724  205031093  14259.334891   26044.0                      35.0
# 14725  205031093  14259.334891   26044.0                      35.0
#
#        scaled_crime_rate
# 0               0.789795
# 1               0.789795
# 2               0.789795
# 3               0.789795
# 4               0.789795
# ...                  ...
# 14721           0.015017
# 14722           0.015017
# 14723           0.015017
# 14724           0.015017
# 14725           0.015017
#
# [14726 rows x 14 columns]

# %%
# df_merge.to_csv('../data/raw/property_merged.csv')
