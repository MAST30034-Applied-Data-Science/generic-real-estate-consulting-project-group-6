# %%
import numpy as np
import pandas as pd
import json
import seaborn as sns
pd.options.mode.chained_assignment = None
# Read the data
# with open('../data/raw/property_raw.json','r',encoding='utf8')as fp:
#     json_data = json.load(fp)

# df = pd.DataFrame(json_data.values())
df = pd.read_csv('../data/raw/property_train_CBD.csv')
df.dropna()
# Out:
#        Unnamed: 0                                               name  \
# 0               0          1901/368 St Kilda Road Melbourne VIC 3000
# 1               1         1211/200 Spencer Street Melbourne VIC 3000
# 2               2  1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3              3/27 Flinders Lane Melbourne VIC 3000
# 4               4         611/408 Lonsdale Street Melbourne VIC 3000
# ...           ...                                                ...
# 15342       15342            28 Beachcomber Drive Inverloch VIC 3996
# 15343       15343             14 Inverloch Parade Inverloch VIC 3996
# 15344       15344              10 Hopetoun Street Inverloch VIC 3996
# 15345       15345                                 Inverloch VIC 3996
# 15346       15346                 64 Dixon Street Inverloch VIC 3996
#
#             cost_text                 coordinates  \
# 0      $1800 Per Week  [-37.8318086, 144.9710272]
# 1       $480 per week   [-37.816228, 144.9532465]
# 2             $400 pw  [-37.8121026, 144.9581291]
# 3       $420 per week  [-37.8147317, 144.9733655]
# 4                $350  [-37.8125979, 144.9604012]
# ...               ...                         ...
# 15342         $550 wk  [-38.6412502, 145.7031282]
# 15343         $420 wk  [-38.6287143, 145.7358082]
# 15344         $370 wk  [-38.6341243, 145.7306862]
# 15345         $475 wk  [-38.6314613, 145.7293638]
# 15346   Contact Agent   [-38.6313719, 145.717275]
#
#                                     rooms                     type  \
# 0      ['3 Beds', '2 Baths', '2 Parking']  Apartment / Unit / Flat
# 1        ['1 Bed', '1 Bath', '1 Parking']  Apartment / Unit / Flat
# 2                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 3                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 4                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# ...                                   ...                      ...
# 15342               ['4 Beds', '2 Baths']                    House
# 15343                ['2 Beds', '1 Bath']                    House
# 15344   ['2 Beds', '1 Bath', '1 Parking']                    House
# 15345  ['3 Beds', '2 Baths', '1 Parking']                    House
# 15346                 ['1 Bed', '1 Bath']                    House
#
#        closest station  proximity to train station  CBD_distance
# 0                   30                     1803.65       1702.19
# 1                  176                      371.68       2267.13
# 2                   28                      248.50       1937.39
# 3                  140                      404.26        790.13
# 4                   28                      525.08       1657.95
# ...                ...                         ...           ...
# 15342              181                    65073.96     146939.64
# 15343              181                    69323.16     147493.50
# 15344              181                    68313.03     147082.53
# 15345              181                    68459.23     146682.64
# 15346              181                    67308.83     145916.84
#
# [15345 rows x 9 columns]

# %%
ps_code = df['name']
ps_code1 = list(ps_code)
add = list(ps_code)
for i in range(len(ps_code1)-1):
    ps_code1[i] = ps_code1[i][-4:]
for i in range(len(add)-1):
    add[i] = add[i][:-9]
    
df['postcode'] = ps_code1
df['address'] = add
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0          1901/368 St Kilda Road Melbourne VIC 3000
# 1               1         1211/200 Spencer Street Melbourne VIC 3000
# 2               2  1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3              3/27 Flinders Lane Melbourne VIC 3000
# 4               4         611/408 Lonsdale Street Melbourne VIC 3000
# ...           ...                                                ...
# 15342       15342            28 Beachcomber Drive Inverloch VIC 3996
# 15343       15343             14 Inverloch Parade Inverloch VIC 3996
# 15344       15344              10 Hopetoun Street Inverloch VIC 3996
# 15345       15345                                 Inverloch VIC 3996
# 15346       15346                 64 Dixon Street Inverloch VIC 3996
#
#             cost_text                 coordinates  \
# 0      $1800 Per Week  [-37.8318086, 144.9710272]
# 1       $480 per week   [-37.816228, 144.9532465]
# 2             $400 pw  [-37.8121026, 144.9581291]
# 3       $420 per week  [-37.8147317, 144.9733655]
# 4                $350  [-37.8125979, 144.9604012]
# ...               ...                         ...
# 15342         $550 wk  [-38.6412502, 145.7031282]
# 15343         $420 wk  [-38.6287143, 145.7358082]
# 15344         $370 wk  [-38.6341243, 145.7306862]
# 15345         $475 wk  [-38.6314613, 145.7293638]
# 15346   Contact Agent   [-38.6313719, 145.717275]
#
#                                     rooms                     type  \
# 0      ['3 Beds', '2 Baths', '2 Parking']  Apartment / Unit / Flat
# 1        ['1 Bed', '1 Bath', '1 Parking']  Apartment / Unit / Flat
# 2                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 3                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 4                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# ...                                   ...                      ...
# 15342               ['4 Beds', '2 Baths']                    House
# 15343                ['2 Beds', '1 Bath']                    House
# 15344   ['2 Beds', '1 Bath', '1 Parking']                    House
# 15345  ['3 Beds', '2 Baths', '1 Parking']                    House
# 15346                 ['1 Bed', '1 Bath']                    House
#
#        closest station  proximity to train station  CBD_distance  \
# 0                   30                     1803.65       1702.19
# 1                  176                      371.68       2267.13
# 2                   28                      248.50       1937.39
# 3                  140                      404.26        790.13
# 4                   28                      525.08       1657.95
# ...                ...                         ...           ...
# 15342              181                    65073.96     146939.64
# 15343              181                    69323.16     147493.50
# 15344              181                    68313.03     147082.53
# 15345              181                    68459.23     146682.64
# 15346              181                    67308.83     145916.84
#
#                                  postcode  \
# 0                                    3000
# 1                                    3000
# 2                                    3000
# 3                                    3000
# 4                                    3000
# ...                                   ...
# 15342                                3996
# 15343                                3996
# 15344                                3996
# 15345                                3996
# 15346  64 Dixon Street Inverloch VIC 3996
#
#                                          address
# 0               1901/368 St Kilda Road Melbourne
# 1              1211/200 Spencer Street Melbourne
# 2      1008/380 Little Lonsdale Street Melbourne
# 3                   3/27 Flinders Lane Melbourne
# 4              611/408 Lonsdale Street Melbourne
# ...                                          ...
# 15342             28 Beachcomber Drive Inverloch
# 15343              14 Inverloch Parade Inverloch
# 15344               10 Hopetoun Street Inverloch
# 15345                                  Inverloch
# 15346         64 Dixon Street Inverloch VIC 3996
#
# [15347 rows x 11 columns]

# %%
# extract cost value
import numpy as np
df['cost'] = df.cost_text.str.extract("(\d*\.?\d+)", expand=True)
df=df.dropna()
df['cost'] = pd.to_numeric(df['cost'])
df['cost'] = df['cost'].astype(int)
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0          1901/368 St Kilda Road Melbourne VIC 3000
# 1               1         1211/200 Spencer Street Melbourne VIC 3000
# 2               2  1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3              3/27 Flinders Lane Melbourne VIC 3000
# 4               4         611/408 Lonsdale Street Melbourne VIC 3000
# ...           ...                                                ...
# 15341       15341          16B Sandy Mount Avenue Inverloch VIC 3996
# 15342       15342            28 Beachcomber Drive Inverloch VIC 3996
# 15343       15343             14 Inverloch Parade Inverloch VIC 3996
# 15344       15344              10 Hopetoun Street Inverloch VIC 3996
# 15345       15345                                 Inverloch VIC 3996
#
#               cost_text                 coordinates  \
# 0        $1800 Per Week  [-37.8318086, 144.9710272]
# 1         $480 per week   [-37.816228, 144.9532465]
# 2               $400 pw  [-37.8121026, 144.9581291]
# 3         $420 per week  [-37.8147317, 144.9733655]
# 4                  $350  [-37.8125979, 144.9604012]
# ...                 ...                         ...
# 15341  $400.00 per week   [-38.6340011, 145.725239]
# 15342           $550 wk  [-38.6412502, 145.7031282]
# 15343           $420 wk  [-38.6287143, 145.7358082]
# 15344           $370 wk  [-38.6341243, 145.7306862]
# 15345           $475 wk  [-38.6314613, 145.7293638]
#
#                                     rooms                     type  \
# 0      ['3 Beds', '2 Baths', '2 Parking']  Apartment / Unit / Flat
# 1        ['1 Bed', '1 Bath', '1 Parking']  Apartment / Unit / Flat
# 2                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 3                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 4                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# ...                                   ...                      ...
# 15341   ['2 Beds', '1 Bath', '1 Parking']                    House
# 15342               ['4 Beds', '2 Baths']                    House
# 15343                ['2 Beds', '1 Bath']                    House
# 15344   ['2 Beds', '1 Bath', '1 Parking']                    House
# 15345  ['3 Beds', '2 Baths', '1 Parking']                    House
#
#        closest station  proximity to train station  CBD_distance postcode  \
# 0                   30                     1803.65       1702.19     3000
# 1                  176                      371.68       2267.13     3000
# 2                   28                      248.50       1937.39     3000
# 3                  140                      404.26        790.13     3000
# 4                   28                      525.08       1657.95     3000
# ...                ...                         ...           ...      ...
# 15341              181                    67815.19     146677.31     3996
# 15342              181                    65073.96     146939.64     3996
# 15343              181                    69323.16     147493.50     3996
# 15344              181                    68313.03     147082.53     3996
# 15345              181                    68459.23     146682.64     3996
#
#                                          address  cost
# 0               1901/368 St Kilda Road Melbourne  1800
# 1              1211/200 Spencer Street Melbourne   480
# 2      1008/380 Little Lonsdale Street Melbourne   400
# 3                   3/27 Flinders Lane Melbourne   420
# 4              611/408 Lonsdale Street Melbourne   350
# ...                                          ...   ...
# 15341           16B Sandy Mount Avenue Inverloch   400
# 15342             28 Beachcomber Drive Inverloch   550
# 15343              14 Inverloch Parade Inverloch   420
# 15344               10 Hopetoun Street Inverloch   370
# 15345                                  Inverloch   475
#
# [14967 rows x 12 columns]

# %%
# extract postcode frome the feature 'name'
df['postcode'] = df['name'].apply(lambda x:x.split(' ')[-1])
df = df.reset_index(drop=True)
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0          1901/368 St Kilda Road Melbourne VIC 3000
# 1               1         1211/200 Spencer Street Melbourne VIC 3000
# 2               2  1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3              3/27 Flinders Lane Melbourne VIC 3000
# 4               4         611/408 Lonsdale Street Melbourne VIC 3000
# ...           ...                                                ...
# 14962       15341          16B Sandy Mount Avenue Inverloch VIC 3996
# 14963       15342            28 Beachcomber Drive Inverloch VIC 3996
# 14964       15343             14 Inverloch Parade Inverloch VIC 3996
# 14965       15344              10 Hopetoun Street Inverloch VIC 3996
# 14966       15345                                 Inverloch VIC 3996
#
#               cost_text                 coordinates  \
# 0        $1800 Per Week  [-37.8318086, 144.9710272]
# 1         $480 per week   [-37.816228, 144.9532465]
# 2               $400 pw  [-37.8121026, 144.9581291]
# 3         $420 per week  [-37.8147317, 144.9733655]
# 4                  $350  [-37.8125979, 144.9604012]
# ...                 ...                         ...
# 14962  $400.00 per week   [-38.6340011, 145.725239]
# 14963           $550 wk  [-38.6412502, 145.7031282]
# 14964           $420 wk  [-38.6287143, 145.7358082]
# 14965           $370 wk  [-38.6341243, 145.7306862]
# 14966           $475 wk  [-38.6314613, 145.7293638]
#
#                                     rooms                     type  \
# 0      ['3 Beds', '2 Baths', '2 Parking']  Apartment / Unit / Flat
# 1        ['1 Bed', '1 Bath', '1 Parking']  Apartment / Unit / Flat
# 2                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 3                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# 4                     ['1 Bed', '1 Bath']  Apartment / Unit / Flat
# ...                                   ...                      ...
# 14962   ['2 Beds', '1 Bath', '1 Parking']                    House
# 14963               ['4 Beds', '2 Baths']                    House
# 14964                ['2 Beds', '1 Bath']                    House
# 14965   ['2 Beds', '1 Bath', '1 Parking']                    House
# 14966  ['3 Beds', '2 Baths', '1 Parking']                    House
#
#        closest station  proximity to train station  CBD_distance postcode  \
# 0                   30                     1803.65       1702.19     3000
# 1                  176                      371.68       2267.13     3000
# 2                   28                      248.50       1937.39     3000
# 3                  140                      404.26        790.13     3000
# 4                   28                      525.08       1657.95     3000
# ...                ...                         ...           ...      ...
# 14962              181                    67815.19     146677.31     3996
# 14963              181                    65073.96     146939.64     3996
# 14964              181                    69323.16     147493.50     3996
# 14965              181                    68313.03     147082.53     3996
# 14966              181                    68459.23     146682.64     3996
#
#                                          address  cost
# 0               1901/368 St Kilda Road Melbourne  1800
# 1              1211/200 Spencer Street Melbourne   480
# 2      1008/380 Little Lonsdale Street Melbourne   400
# 3                   3/27 Flinders Lane Melbourne   420
# 4              611/408 Lonsdale Street Melbourne   350
# ...                                          ...   ...
# 14962           16B Sandy Mount Avenue Inverloch   400
# 14963             28 Beachcomber Drive Inverloch   550
# 14964              14 Inverloch Parade Inverloch   420
# 14965               10 Hopetoun Street Inverloch   370
# 14966                                  Inverloch   475
#
# [14967 rows x 12 columns]

# %%
# the feature rooms have is string type, convert to list
import ast
df['rooms'] = df['rooms'].map(lambda x : ast.literal_eval(x))

# %%
# split rooms into different part
# count missing values in 'rooms'
list(df['rooms']).count([])
# remove missing value
df=df[df['rooms'].str.len() != 0]


df = df.reset_index(drop=True)
rooms =df['rooms']

bedroom = []
bath = []
parking = []

for i in range(len(rooms)):
    if (rooms[i][0][-4:] == 'Beds') or (rooms[i][0][-3:] == 'Bed'):
        bedroom.append(rooms[i][0][0])
       
for j in range(len(rooms)):
    if (rooms[j][1][-5:] == 'Baths') or (rooms[j][1][-4:] == 'Bath'):
        bath.append(rooms[j][1][0])

for j in range(len(rooms)):
    if len(rooms[j]) != 3:
        parking.append('0')
    elif(rooms[j][2][2:] == 'Parking'):
        parking.append(rooms[j][2][0])

df['beds'] = bedroom
df['bath'] = bath
df['parking'] = parking
df
# Out:
#        Unnamed: 0                                               name  \
# 0               0          1901/368 St Kilda Road Melbourne VIC 3000
# 1               1         1211/200 Spencer Street Melbourne VIC 3000
# 2               2  1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3              3/27 Flinders Lane Melbourne VIC 3000
# 4               4         611/408 Lonsdale Street Melbourne VIC 3000
# ...           ...                                                ...
# 14936       15341          16B Sandy Mount Avenue Inverloch VIC 3996
# 14937       15342            28 Beachcomber Drive Inverloch VIC 3996
# 14938       15343             14 Inverloch Parade Inverloch VIC 3996
# 14939       15344              10 Hopetoun Street Inverloch VIC 3996
# 14940       15345                                 Inverloch VIC 3996
#
#               cost_text                 coordinates  \
# 0        $1800 Per Week  [-37.8318086, 144.9710272]
# 1         $480 per week   [-37.816228, 144.9532465]
# 2               $400 pw  [-37.8121026, 144.9581291]
# 3         $420 per week  [-37.8147317, 144.9733655]
# 4                  $350  [-37.8125979, 144.9604012]
# ...                 ...                         ...
# 14936  $400.00 per week   [-38.6340011, 145.725239]
# 14937           $550 wk  [-38.6412502, 145.7031282]
# 14938           $420 wk  [-38.6287143, 145.7358082]
# 14939           $370 wk  [-38.6341243, 145.7306862]
# 14940           $475 wk  [-38.6314613, 145.7293638]
#
#                               rooms                     type  closest station  \
# 0      [3 Beds, 2 Baths, 2 Parking]  Apartment / Unit / Flat               30
# 1        [1 Bed, 1 Bath, 1 Parking]  Apartment / Unit / Flat              176
# 2                   [1 Bed, 1 Bath]  Apartment / Unit / Flat               28
# 3                   [1 Bed, 1 Bath]  Apartment / Unit / Flat              140
# 4                   [1 Bed, 1 Bath]  Apartment / Unit / Flat               28
# ...                             ...                      ...              ...
# 14936   [2 Beds, 1 Bath, 1 Parking]                    House              181
# 14937             [4 Beds, 2 Baths]                    House              181
# 14938              [2 Beds, 1 Bath]                    House              181
# 14939   [2 Beds, 1 Bath, 1 Parking]                    House              181
# 14940  [3 Beds, 2 Baths, 1 Parking]                    House              181
#
#        proximity to train station  CBD_distance postcode  \
# 0                         1803.65       1702.19     3000
# 1                          371.68       2267.13     3000
# 2                          248.50       1937.39     3000
# 3                          404.26        790.13     3000
# 4                          525.08       1657.95     3000
# ...                           ...           ...      ...
# 14936                    67815.19     146677.31     3996
# 14937                    65073.96     146939.64     3996
# 14938                    69323.16     147493.50     3996
# 14939                    68313.03     147082.53     3996
# 14940                    68459.23     146682.64     3996
#
#                                          address  cost beds bath parking
# 0               1901/368 St Kilda Road Melbourne  1800    3    2       2
# 1              1211/200 Spencer Street Melbourne   480    1    1       1
# 2      1008/380 Little Lonsdale Street Melbourne   400    1    1       0
# 3                   3/27 Flinders Lane Melbourne   420    1    1       0
# 4              611/408 Lonsdale Street Melbourne   350    1    1       0
# ...                                          ...   ...  ...  ...     ...
# 14936           16B Sandy Mount Avenue Inverloch   400    2    1       1
# 14937             28 Beachcomber Drive Inverloch   550    4    2       0
# 14938              14 Inverloch Parade Inverloch   420    2    1       0
# 14939               10 Hopetoun Street Inverloch   370    2    1       1
# 14940                                  Inverloch   475    3    2       1
#
# [14941 rows x 15 columns]

# %%
# read postcode file and remove duplicates on 'postcode'
postcode_df = pd.read_csv("../data/raw/external_data/australian_postcodes.csv")
postcode_df = postcode_df.drop_duplicates(subset=['postcode'])

# The 'postcode' value types in the two dataframe are different. Convert df to int
df['postcode'] = pd.to_numeric(df['postcode']).astype(int)

# merge two dataframe and select features
df_merge = df.merge(postcode_df,on="postcode",how="left")
df_merge = df_merge[['name','cost','coordinates','type_x','address','beds','proximity to train station','CBD_distance','bath','parking','postcode','SA2_MAINCODE_2016']]

# %%
crime = pd.read_csv('../data/raw/external_data/crime_completed.csv', index_col=[0])
crime
# Out:
#      postcode  Offence Count     SA2 code  ERP 2021      scaled  \
# 0        3000          37272  206041122.0   47192.0    0.789795
# 1        3002           2429  206041119.0    5803.0    0.418577
# 2        3003           2708  206041127.0       3.0  902.666667
# 3        3004           2415  412082251.0   32825.0    0.073572
# 4        3005            174  206041118.0   14821.0    0.011740
# ..        ...            ...          ...       ...         ...
# 691      3990              5  205031093.0   26044.0    0.000192
# 692      3991            118  205031093.0   26044.0    0.004531
# 693      3992            206  205031093.0   26044.0    0.007910
# 694      3995           2179  205031093.0   26044.0    0.083666
# 695      3996            531  410062180.0   35361.0    0.015017
#
#      scaled_crime_rate
# 0             0.789795
# 1             0.418577
# 2           902.666667
# 3             0.073572
# 4             0.011740
# ..                 ...
# 691           0.000192
# 692           0.004531
# 693           0.007910
# 694           0.083666
# 695           0.015017
#
# [696 rows x 6 columns]

# %%
df_merge = df_merge.rename(columns={'proximity to train station' : 'station_distance', 'type_x' : 'type', 'SA2_MAINCODE_2016' : 'SA2_CODE'})
df_merge['SA2_CODE'] = df_merge['SA2_CODE'].astype('int64')
income_df = pd.read_csv('../data/raw/external_data/income_complete.csv')
income_df = income_df.rename(columns={'SA2' : 'SA2_CODE'})
df_merge = pd.merge(df_merge, income_df[['SA2_CODE', '2022 pred']], on="SA2_CODE", how="left")
population = pd.read_csv('../data/raw/external_data/population_complete.csv')
population = population.rename(columns={'SA2 code' : 'SA2_CODE'})
df_merge = pd.merge(df_merge, population[['SA2_CODE', 'ERP 2021', 'density 2021 persons/km2']], on="SA2_CODE", how="left")
crime = pd.read_csv('../data/raw/external_data/crime_completed.csv', index_col=[0])
df_merge = pd.merge(df_merge, crime[['postcode', 'scaled_crime_rate']], on='postcode', how='left')
df_merge
# Out:
#                                                     name  cost  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  1800
# 1             1211/200 Spencer Street Melbourne VIC 3000   480
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...   400
# 3                  3/27 Flinders Lane Melbourne VIC 3000   420
# 4             611/408 Lonsdale Street Melbourne VIC 3000   350
# ...                                                  ...   ...
# 14936          16B Sandy Mount Avenue Inverloch VIC 3996   400
# 14937            28 Beachcomber Drive Inverloch VIC 3996   550
# 14938             14 Inverloch Parade Inverloch VIC 3996   420
# 14939              10 Hopetoun Street Inverloch VIC 3996   370
# 14940                                 Inverloch VIC 3996   475
#
#                       coordinates                     type  \
# 0      [-37.8318086, 144.9710272]  Apartment / Unit / Flat
# 1       [-37.816228, 144.9532465]  Apartment / Unit / Flat
# 2      [-37.8121026, 144.9581291]  Apartment / Unit / Flat
# 3      [-37.8147317, 144.9733655]  Apartment / Unit / Flat
# 4      [-37.8125979, 144.9604012]  Apartment / Unit / Flat
# ...                           ...                      ...
# 14936   [-38.6340011, 145.725239]                    House
# 14937  [-38.6412502, 145.7031282]                    House
# 14938  [-38.6287143, 145.7358082]                    House
# 14939  [-38.6341243, 145.7306862]                    House
# 14940  [-38.6314613, 145.7293638]                    House
#
#                                          address beds  station_distance  \
# 0               1901/368 St Kilda Road Melbourne    3           1803.65
# 1              1211/200 Spencer Street Melbourne    1            371.68
# 2      1008/380 Little Lonsdale Street Melbourne    1            248.50
# 3                   3/27 Flinders Lane Melbourne    1            404.26
# 4              611/408 Lonsdale Street Melbourne    1            525.08
# ...                                          ...  ...               ...
# 14936           16B Sandy Mount Avenue Inverloch    2          67815.19
# 14937             28 Beachcomber Drive Inverloch    4          65073.96
# 14938              14 Inverloch Parade Inverloch    2          69323.16
# 14939               10 Hopetoun Street Inverloch    2          68313.03
# 14940                                  Inverloch    3          68459.23
#
#        CBD_distance bath parking  postcode   SA2_CODE     2022 pred  ERP 2021  \
# 0           1702.19    2       2      3000  206041122  30531.488067   47192.0
# 1           2267.13    1       1      3000  206041122  30531.488067   47192.0
# 2           1937.39    1       0      3000  206041122  30531.488067   47192.0
# 3            790.13    1       0      3000  206041122  30531.488067   47192.0
# 4           1657.95    1       0      3000  206041122  30531.488067   47192.0
# ...             ...  ...     ...       ...        ...           ...       ...
# 14936     146677.31    1       1      3996  205031093  14259.334891   26044.0
# 14937     146939.64    2       0      3996  205031093  14259.334891   26044.0
# 14938     147493.50    1       0      3996  205031093  14259.334891   26044.0
# 14939     147082.53    1       1      3996  205031093  14259.334891   26044.0
# 14940     146682.64    2       1      3996  205031093  14259.334891   26044.0
#
#        density 2021 persons/km2  scaled_crime_rate
# 0                       19920.0           0.789795
# 1                       19920.0           0.789795
# 2                       19920.0           0.789795
# 3                       19920.0           0.789795
# 4                       19920.0           0.789795
# ...                         ...                ...
# 14936                      35.0           0.015017
# 14937                      35.0           0.015017
# 14938                      35.0           0.015017
# 14939                      35.0           0.015017
# 14940                      35.0           0.015017
#
# [14941 rows x 16 columns]

# %%
df_merge.to_csv('../data/raw/property_merged.csv')
