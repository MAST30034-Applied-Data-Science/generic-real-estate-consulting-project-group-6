# %%
import numpy as np
import pandas as pd
import json
pd.options.mode.chained_assignment = None
# Read the yellow taxis data
with open('../data/raw/property_raw.json','r',encoding='utf8')as fp:
    json_data = json.load(fp)

df = pd.DataFrame(json_data.values())
df.dropna()
# Out:
#                                                     name       cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000   $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...         $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000   $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000            $350
# ...                                                  ...             ...
# 15342            28 Beachcomber Drive Inverloch VIC 3996         $550 wk
# 15343             14 Inverloch Parade Inverloch VIC 3996         $420 wk
# 15344              10 Hopetoun Street Inverloch VIC 3996         $370 wk
# 15345                                 Inverloch VIC 3996         $475 wk
# 15346                 64 Dixon Street Inverloch VIC 3996   Contact Agent
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 15342  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 15343  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 15344  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 15345  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
# 15346   [-38.6313719, 145.717275]               [1 Bed, 1 Bath]
#
#                           type
# 0      Apartment / Unit / Flat
# 1      Apartment / Unit / Flat
# 2      Apartment / Unit / Flat
# 3      Apartment / Unit / Flat
# 4      Apartment / Unit / Flat
# ...                        ...
# 15342                    House
# 15343                    House
# 15344                    House
# 15345                    House
# 15346                    House
#
# [15347 rows x 5 columns]

# %%
ps_code = df['name']
ps_code1 = list(ps_code)
add = list(ps_code)
for i in range(len(ps_code1)-1):
    ps_code1[i] = ps_code1[i][-4:]
for i in range(len(add)-1):
    add[i] = add[i][:-9]
    
df['postcode'] = ps_code1
df['address'] = add
df.head(30)
# Out:
#                                                  name  \
# 0           1901/368 St Kilda Road Melbourne VIC 3000
# 1          1211/200 Spencer Street Melbourne VIC 3000
# 2   1008/380 Little Lonsdale Street Melbourne VIC ...
# 3               3/27 Flinders Lane Melbourne VIC 3000
# 4          611/408 Lonsdale Street Melbourne VIC 3000
# 5                102/9 Bligh Place Melbourne VIC 3000
# 6          1715/220 Spencer Street Melbourne VIC 3000
# 7          104/300 Swanston Street Melbourne VIC 3000
# 8         Unit 1713/200 Spencer St Melbourne VIC 3000
# 9                701/101 Therry St Melbourne VIC 3000
# 10               816/101 Therry St Melbourne VIC 3000
# 11         3902/220 Spencer Street Melbourne VIC 3000
# 12         3405/288 Spencer Street Melbourne VIC 3000
# 13            1007/238 Flinders St Melbourne VIC 3000
# 14         1211/260 Spencer Street Melbourne VIC 3000
# 15         504/350 La Trobe Street Melbourne VIC 3000
# 16        1106/555 Flinders Street Melbourne VIC 3000
# 17         5401/464 Collins Street Melbourne VIC 3000
# 18         625/118 Franklin Street Melbourne VIC 3000
# 19         1206/118 Russell Street Melbourne VIC 3000
# 20           1411/120 A Beckett St Melbourne VIC 3000
# 21        1313/268 Flinders Street Melbourne VIC 3000
# 22     5003/464-466 Collins Street Melbourne VIC 3000
# 23          912/87 Franklin Street Melbourne VIC 3000
# 24       1011/225 Elizabeth Street Melbourne VIC 3000
# 25          405/325 Collins Street Melbourne VIC 3000
# 26           3108/500 Elizabeth St Melbourne VIC 3000
# 27                55/1 Albert Road Melbourne VIC 3000
# 28                 228 La Trobe St Melbourne VIC 3000
# 29         Unit 913/39 Lonsdale St Melbourne VIC 3000
#
#                                     cost_text  \
# 0                              $1800 Per Week
# 1                               $480 per week
# 2                                     $400 pw
# 3                               $420 per week
# 4                                        $350
# 5                                        $600
# 6                                        $600
# 7                                        $550
# 8                               $440 per week
# 9         NEW corner apartment Keep your bond
# 10  New apartment No bond needed Pets welcome
# 11                              $650 per week
# 12                                       $440
# 13                                       $320
# 14                                       $700
# 15                              $395 per week
# 16                              $370 per week
# 17                             $2500 Per Week
# 18                                       $530
# 19                              $550 per week
# 20                                       $680
# 21                              $350 per week
# 22                              $550 Per Week
# 23                              $450 per week
# 24                              $430 per week
# 25                           $420.00 per week
# 26                                       $410
# 27                              $950 Per Week
# 28                                       70pw
# 29                              $420 per week
#
#                           coordinates                         rooms  \
# 0          [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1           [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2          [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3          [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4          [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# 5             [-37.817317, 144.96371]   [2 Beds, 1 Bath, 1 Parking]
# 6          [-37.8157157, 144.9529559]  [2 Beds, 2 Baths, 1 Parking]
# 7          [-37.8106088, 144.9645798]              [2 Beds, 1 Bath]
# 8           [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 9          [-37.8074149, 144.9591227]               [1 Bed, 1 Bath]
# 10         [-37.8074149, 144.9591227]             [2 Beds, 2 Baths]
# 11         [-37.8157157, 144.9529559]  [2 Beds, 2 Baths, 1 Parking]
# 12          [-37.813775, 144.9520948]               [1 Bed, 1 Bath]
# 13         [-37.8175167, 144.9664983]               [1 Bed, 1 Bath]
# 14          [-37.814564, 144.9522856]             [2 Beds, 2 Baths]
# 15         [-37.8106785, 144.9592774]              [2 Beds, 1 Bath]
# 16         [-37.8209711, 144.9564827]               [1 Bed, 1 Bath]
# 17         [-37.8175602, 144.9585916]  [3 Beds, 3 Baths, 2 Parking]
# 18         [-37.8082052, 144.9589035]             [3 Beds, 2 Baths]
# 19         [-37.8135864, 144.9687232]              [2 Beds, 1 Bath]
# 20         [-37.8093086, 144.9597389]             [2 Beds, 2 Baths]
# 21         [-37.8178134, 144.9655688]              [2 Beds, 1 Bath]
# 22   [-37.81755500000001, 144.958633]    [1 Bed, 1 Bath, 1 Parking]
# 23         [-37.8079392, 144.9617069]    [1 Bed, 1 Bath, 1 Parking]
# 24         [-37.8132308, 144.9623173]               [1 Bed, 1 Bath]
# 25         [-37.8166442, 144.9635498]              [2 Beds, 1 Bath]
# 26         [-37.8072443, 144.9602814]               [1 Bed, 1 Bath]
# 27           [-37.833957, 144.972793]  [2 Beds, 2 Baths, 2 Parking]
# 28         [-37.8097514, 144.9626141]   [0 Beds, 1 Bath, 1 Parking]
# 29  [-37.80992639999999, 144.9711317]              [2 Beds, 1 Bath]
#
#                        type postcode  \
# 0   Apartment / Unit / Flat     3000
# 1   Apartment / Unit / Flat     3000
# 2   Apartment / Unit / Flat     3000
# 3   Apartment / Unit / Flat     3000
# 4   Apartment / Unit / Flat     3000
# 5   Apartment / Unit / Flat     3000
# 6   Apartment / Unit / Flat     3000
# 7   Apartment / Unit / Flat     3000
# 8   Apartment / Unit / Flat     3000
# 9   Apartment / Unit / Flat     3000
# 10  Apartment / Unit / Flat     3000
# 11  Apartment / Unit / Flat     3000
# 12  Apartment / Unit / Flat     3000
# 13  Apartment / Unit / Flat     3000
# 14  Apartment / Unit / Flat     3000
# 15  Apartment / Unit / Flat     3000
# 16  Apartment / Unit / Flat     3000
# 17  Apartment / Unit / Flat     3000
# 18  Apartment / Unit / Flat     3000
# 19  Apartment / Unit / Flat     3000
# 20  Apartment / Unit / Flat     3000
# 21  Apartment / Unit / Flat     3000
# 22  Apartment / Unit / Flat     3000
# 23  Apartment / Unit / Flat     3000
# 24  Apartment / Unit / Flat     3000
# 25  Apartment / Unit / Flat     3000
# 26  Apartment / Unit / Flat     3000
# 27  Apartment / Unit / Flat     3000
# 28                 Carspace     3000
# 29  Apartment / Unit / Flat     3000
#
#                                       address
# 0            1901/368 St Kilda Road Melbourne
# 1           1211/200 Spencer Street Melbourne
# 2   1008/380 Little Lonsdale Street Melbourne
# 3                3/27 Flinders Lane Melbourne
# 4           611/408 Lonsdale Street Melbourne
# 5                 102/9 Bligh Place Melbourne
# 6           1715/220 Spencer Street Melbourne
# 7           104/300 Swanston Street Melbourne
# 8          Unit 1713/200 Spencer St Melbourne
# 9                 701/101 Therry St Melbourne
# 10                816/101 Therry St Melbourne
# 11          3902/220 Spencer Street Melbourne
# 12          3405/288 Spencer Street Melbourne
# 13             1007/238 Flinders St Melbourne
# 14          1211/260 Spencer Street Melbourne
# 15          504/350 La Trobe Street Melbourne
# 16         1106/555 Flinders Street Melbourne
# 17          5401/464 Collins Street Melbourne
# 18          625/118 Franklin Street Melbourne
# 19          1206/118 Russell Street Melbourne
# 20            1411/120 A Beckett St Melbourne
# 21         1313/268 Flinders Street Melbourne
# 22      5003/464-466 Collins Street Melbourne
# 23           912/87 Franklin Street Melbourne
# 24        1011/225 Elizabeth Street Melbourne
# 25           405/325 Collins Street Melbourne
# 26            3108/500 Elizabeth St Melbourne
# 27                 55/1 Albert Road Melbourne
# 28                  228 La Trobe St Melbourne
# 29          Unit 913/39 Lonsdale St Melbourne

# %%
# extract cost value
import numpy as np
df['cost'] = df.cost_text.str.extract("(\d*\.?\d+)", expand=True)
df=df.dropna()
df['cost'] = pd.to_numeric(df['cost'])
df['cost'] = df['cost'].astype(int)
df
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 15341          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 15342            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 15343             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 15344              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 15345                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 15341   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 15342  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 15343  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 15344  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 15345  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type postcode  \
# 0      Apartment / Unit / Flat     3000
# 1      Apartment / Unit / Flat     3000
# 2      Apartment / Unit / Flat     3000
# 3      Apartment / Unit / Flat     3000
# 4      Apartment / Unit / Flat     3000
# ...                        ...      ...
# 15341                    House     3996
# 15342                    House     3996
# 15343                    House     3996
# 15344                    House     3996
# 15345                    House     3996
#
#                                          address  cost
# 0               1901/368 St Kilda Road Melbourne  1800
# 1              1211/200 Spencer Street Melbourne   480
# 2      1008/380 Little Lonsdale Street Melbourne   400
# 3                   3/27 Flinders Lane Melbourne   420
# 4              611/408 Lonsdale Street Melbourne   350
# ...                                          ...   ...
# 15341           16B Sandy Mount Avenue Inverloch   400
# 15342             28 Beachcomber Drive Inverloch   550
# 15343              14 Inverloch Parade Inverloch   420
# 15344               10 Hopetoun Street Inverloch   370
# 15345                                  Inverloch   475
#
# [14969 rows x 8 columns]

# %%
# extract postcode frome the feature 'name'
df['postcode'] = df['name'].apply(lambda x:x.split(' ')[-1])
df = df.reset_index(drop=True)
df
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14964          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14965            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14966             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14967              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14968                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14964   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14965  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14966  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14967  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14968  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type postcode  \
# 0      Apartment / Unit / Flat     3000
# 1      Apartment / Unit / Flat     3000
# 2      Apartment / Unit / Flat     3000
# 3      Apartment / Unit / Flat     3000
# 4      Apartment / Unit / Flat     3000
# ...                        ...      ...
# 14964                    House     3996
# 14965                    House     3996
# 14966                    House     3996
# 14967                    House     3996
# 14968                    House     3996
#
#                                          address  cost
# 0               1901/368 St Kilda Road Melbourne  1800
# 1              1211/200 Spencer Street Melbourne   480
# 2      1008/380 Little Lonsdale Street Melbourne   400
# 3                   3/27 Flinders Lane Melbourne   420
# 4              611/408 Lonsdale Street Melbourne   350
# ...                                          ...   ...
# 14964           16B Sandy Mount Avenue Inverloch   400
# 14965             28 Beachcomber Drive Inverloch   550
# 14966              14 Inverloch Parade Inverloch   420
# 14967               10 Hopetoun Street Inverloch   370
# 14968                                  Inverloch   475
#
# [14969 rows x 8 columns]

# %%
# split rooms into different part
# count missing values in 'rooms'
list(df['rooms']).count([])
# remove missing value
df=df[~df['rooms'].isin([[]])]
df = df.reset_index(drop=True)
rooms =df['rooms']

bedroom = []
bath = []
parking = []

for i in range(len(rooms)):
    if (rooms[i][0][-4:] == 'Beds') or (rooms[i][0][-3:] == 'Bed'):
        bedroom.append(rooms[i][0][0])
       
for j in range(len(rooms)):
    if (rooms[j][1][-5:] == 'Baths') or (rooms[j][1][-4:] == 'Bath'):
        bath.append(rooms[j][1][0])

for j in range(len(rooms)):
    if len(rooms[j]) != 3:
        parking.append('0')
    elif(rooms[j][2][2:] == 'Parking'):
        parking.append(rooms[j][2][0])

df['beds'] = bedroom
df['bath'] = bath
df['parking'] = parking
df
# Out:
#                                                     name         cost_text  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000    $1800 Per Week
# 1             1211/200 Spencer Street Melbourne VIC 3000     $480 per week
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...           $400 pw
# 3                  3/27 Flinders Lane Melbourne VIC 3000     $420 per week
# 4             611/408 Lonsdale Street Melbourne VIC 3000              $350
# ...                                                  ...               ...
# 14938          16B Sandy Mount Avenue Inverloch VIC 3996  $400.00 per week
# 14939            28 Beachcomber Drive Inverloch VIC 3996           $550 wk
# 14940             14 Inverloch Parade Inverloch VIC 3996           $420 wk
# 14941              10 Hopetoun Street Inverloch VIC 3996           $370 wk
# 14942                                 Inverloch VIC 3996           $475 wk
#
#                       coordinates                         rooms  \
# 0      [-37.8318086, 144.9710272]  [3 Beds, 2 Baths, 2 Parking]
# 1       [-37.816228, 144.9532465]    [1 Bed, 1 Bath, 1 Parking]
# 2      [-37.8121026, 144.9581291]               [1 Bed, 1 Bath]
# 3      [-37.8147317, 144.9733655]               [1 Bed, 1 Bath]
# 4      [-37.8125979, 144.9604012]               [1 Bed, 1 Bath]
# ...                           ...                           ...
# 14938   [-38.6340011, 145.725239]   [2 Beds, 1 Bath, 1 Parking]
# 14939  [-38.6412502, 145.7031282]             [4 Beds, 2 Baths]
# 14940  [-38.6287143, 145.7358082]              [2 Beds, 1 Bath]
# 14941  [-38.6341243, 145.7306862]   [2 Beds, 1 Bath, 1 Parking]
# 14942  [-38.6314613, 145.7293638]  [3 Beds, 2 Baths, 1 Parking]
#
#                           type postcode  \
# 0      Apartment / Unit / Flat     3000
# 1      Apartment / Unit / Flat     3000
# 2      Apartment / Unit / Flat     3000
# 3      Apartment / Unit / Flat     3000
# 4      Apartment / Unit / Flat     3000
# ...                        ...      ...
# 14938                    House     3996
# 14939                    House     3996
# 14940                    House     3996
# 14941                    House     3996
# 14942                    House     3996
#
#                                          address  cost beds bath parking
# 0               1901/368 St Kilda Road Melbourne  1800    3    2       2
# 1              1211/200 Spencer Street Melbourne   480    1    1       1
# 2      1008/380 Little Lonsdale Street Melbourne   400    1    1       0
# 3                   3/27 Flinders Lane Melbourne   420    1    1       0
# 4              611/408 Lonsdale Street Melbourne   350    1    1       0
# ...                                          ...   ...  ...  ...     ...
# 14938           16B Sandy Mount Avenue Inverloch   400    2    1       1
# 14939             28 Beachcomber Drive Inverloch   550    4    2       0
# 14940              14 Inverloch Parade Inverloch   420    2    1       0
# 14941               10 Hopetoun Street Inverloch   370    2    1       1
# 14942                                  Inverloch   475    3    2       1
#
# [14943 rows x 11 columns]

# %%
# read postcode file and remove duplicates on 'postcode'
postcode_df = pd.read_csv("../data/raw/external_data/australian_postcodes.csv")
postcode_df = postcode_df.drop_duplicates(subset=['postcode'])

# The 'postcode' value types in the two dataframe are different. Convert df to int
df['postcode'] = pd.to_numeric(df['postcode']).astype(int)

# merge two dataframe and select features
df_merge = df.merge(postcode_df,on="postcode",how="left")
df_merge = df_merge[['name','cost','coordinates','type_x','address','beds','bath','parking','postcode','SA2_MAINCODE_2016']]
df_merge
# Out:
#                                                     name  cost  \
# 0              1901/368 St Kilda Road Melbourne VIC 3000  1800
# 1             1211/200 Spencer Street Melbourne VIC 3000   480
# 2      1008/380 Little Lonsdale Street Melbourne VIC ...   400
# 3                  3/27 Flinders Lane Melbourne VIC 3000   420
# 4             611/408 Lonsdale Street Melbourne VIC 3000   350
# ...                                                  ...   ...
# 14938          16B Sandy Mount Avenue Inverloch VIC 3996   400
# 14939            28 Beachcomber Drive Inverloch VIC 3996   550
# 14940             14 Inverloch Parade Inverloch VIC 3996   420
# 14941              10 Hopetoun Street Inverloch VIC 3996   370
# 14942                                 Inverloch VIC 3996   475
#
#                       coordinates                   type_x  \
# 0      [-37.8318086, 144.9710272]  Apartment / Unit / Flat
# 1       [-37.816228, 144.9532465]  Apartment / Unit / Flat
# 2      [-37.8121026, 144.9581291]  Apartment / Unit / Flat
# 3      [-37.8147317, 144.9733655]  Apartment / Unit / Flat
# 4      [-37.8125979, 144.9604012]  Apartment / Unit / Flat
# ...                           ...                      ...
# 14938   [-38.6340011, 145.725239]                    House
# 14939  [-38.6412502, 145.7031282]                    House
# 14940  [-38.6287143, 145.7358082]                    House
# 14941  [-38.6341243, 145.7306862]                    House
# 14942  [-38.6314613, 145.7293638]                    House
#
#                                          address beds bath parking  postcode  \
# 0               1901/368 St Kilda Road Melbourne    3    2       2      3000
# 1              1211/200 Spencer Street Melbourne    1    1       1      3000
# 2      1008/380 Little Lonsdale Street Melbourne    1    1       0      3000
# 3                   3/27 Flinders Lane Melbourne    1    1       0      3000
# 4              611/408 Lonsdale Street Melbourne    1    1       0      3000
# ...                                          ...  ...  ...     ...       ...
# 14938           16B Sandy Mount Avenue Inverloch    2    1       1      3996
# 14939             28 Beachcomber Drive Inverloch    4    2       0      3996
# 14940              14 Inverloch Parade Inverloch    2    1       0      3996
# 14941               10 Hopetoun Street Inverloch    2    1       1      3996
# 14942                                  Inverloch    3    2       1      3996
#
#        SA2_MAINCODE_2016
# 0            206041122.0
# 1            206041122.0
# 2            206041122.0
# 3            206041122.0
# 4            206041122.0
# ...                  ...
# 14938        205031093.0
# 14939        205031093.0
# 14940        205031093.0
# 14941        205031093.0
# 14942        205031093.0
#
# [14943 rows x 10 columns]
