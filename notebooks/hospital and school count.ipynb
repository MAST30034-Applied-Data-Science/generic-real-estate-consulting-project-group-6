# %%
# import libraries
# read in the hospital data

import pandas as pd
import numpy as np
import seaborn as sns

df_hospital =  pd.read_csv('../generic-real-estate-consulting-project-group-6/data/raw/MainHospitalList.csv',header=0)
df_hospital
# Out:
#      Hospital ID                              Formal Name  \
# 0           5488                       Albert Road Clinic
# 1           3485                    Albury Wodonga Health
# 2          12990     Albury Wodonga Health, Albury Campus
# 3           3491                Alexandra District Health
# 4          11519                            Alfred Health
# ..           ...                                      ...
# 265         2569  Yackandandah Bush Nursing Hospital Inc.
# 266        12581                      Yarra Ranges Health
# 267         3324       Yarram and District Health Service
# 268        11271                        Yarrawonga Health
# 269         3554       Yea and District Memorial Hospital
#
#                                   Other Name Emergency Capable  \
# 0                         Albert Road Clinic                NO
# 1                      Albury Wodonga Health               YES
# 2       Albury Wodonga Health, Albury Campus               YES
# ...

# %%
# Count Victoria ten suburbs with the most hospitals
 

df_suburb = df_hospital.Suburb
df_count_hospital = df_suburb.value_counts()
hospital_data = df_count_hospital[0:10]
hospital_data.head(10)
# Out:
# Frankston         8
# Parkville         7
# East Melbourne    7
# Kew               6
# Clayton           6
# Melbourne         6
# Footscray         6
# Geelong           5
# Dandenong         5
# Heidelberg        5
# Name: Suburb, dtype: int64

# %%
# Visualize the top ten suburbs with the most hospitals in Victoria

sns.barplot(x=hospital_data.values, y=hospital_data.keys())
# Out:
# <AxesSubplot:>

# %%
# Read in the school data

df_school =  pd.read_csv('../generic-real-estate-consulting-project-group-6/data/raw/dv309_schoollocations2021.csv', sep=",", encoding='cp1252')
df_school
# Out:
#      Education_Sector  Entity_Type  SCHOOL_NO  \
# 0          Government            1          1
# 1          Government            1          3
# 2          Government            1          4
# 3          Government            1          8
# 4          Government            1         12
# ...               ...          ...        ...
# 2286      Independent            2       2236
# 2287         Catholic            2       2237
# 2288      Independent            2       2238
# 2289      Independent            2       2239
# 2290         Catholic            2       2240
#
#                                  School_Name School_Type School_Status  \
# 0                    Alberton Primary School     Primary             O
# 1     Allansford and District Primary School     Primary             O
# 2                       Avoca Primary School     Primary             O
# 3                      Avenel Primary School     Primary             O
# ...

# %%
# Count Victoria ten suburbs with the most schools
# As there are 3 suburbs have 10 schools, the data will choose top 11

df_Postal_Town = df_school.Postal_Town
df_count_school = df_Postal_Town.value_counts()
school_data = df_count_school[0:11]
school_data.head(11)
# Out:
# WERRIBEE         17
# ST ALBANS        13
# WANGARATTA       12
# GLEN WAVERLEY    12
# CRANBOURNE       11
# MILDURA          11
# SHEPPARTON       11
# SUNBURY          11
# KEW              10
# BALLARAT         10
# MELTON           10
# Name: Postal_Town, dtype: int64

# %%
#Visualize the top ten suburbs with the most schools in Victoria

sns.barplot(x=school_data.values, y=school_data.keys())
# Out:
# <AxesSubplot:>
